# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Goal
# - Check data integrity (NaN, duplicates)
# - Experiment with grouping  and filtering data
# - Experiment with different charts

# %%
pip install streamlit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: streamlit in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (1.27.1)
# Requirement already satisfied: altair<6,>=4.0 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from streamlit) (5.1.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from streamlit) (5.3.1)
# Requirement already satisfied: click<9,>=7.0 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from streamlit) (6.8.0)
# Requirement already satisfied: numpy<2,>=1.19.3 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from streamlit) (1.26.0)
# Requirement already satisfied: packaging<24,>=16.8 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from streamlit) (23.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from streamlit) (2.1.1)
# Requirement already satisfied: pillow<11,>=7.1.0 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from streamlit) (10.0.1)
# Requirement already satisfied: protobuf<5,>=3.20 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from streamlit) (4.24.3)
# Requirement already satisfied: pyarrow>=6.0 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from streamlit) (13.0.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: requests<3,>=2.27 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from streamlit) (13.6.0)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from streamlit) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.1.0 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from streamlit) (4.8.0)
# Requirement already satisfied: tzlocal<6,>=1.1 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: validators<1,>=0.2 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from streamlit) (0.22.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from streamlit) (3.1.37)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from streamlit) (0.8.1b0)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from streamlit) (6.3.3)
# Requirement already satisfied: jinja2 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from altair<6,>=4.0->streamlit) (4.19.1)
# Requirement already satisfied: toolz in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from importlib-metadata<7,>=1.4->streamlit) (3.17.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil<3,>=2.7.3->streamlit) (1.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.27->streamlit) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.27->streamlit) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.27->streamlit) (2023.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from rich<14,>=10.14.0->streamlit) (2.16.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.3)
# Requirement already satisfied: mdurl~=0.1 in /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Importing libraries
import streamlit as st
import pandas as pd 
import plotly_express as px

st.write("""
### Sergey Medvedev Sprint 6 Project
""")

st.write("""
#### Table of data
""")

df = pd.read_csv('/Users/sergeymedvedev/Downloads/vehicles_us.csv')
# Out:
# 2023-10-04 12:54:47.705
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/sergeymedvedev/Library/Python/3.9/lib/python/site-packages/ipykernel_launcher.py [ARGUMENTS]

# %%
print(df.head(5))
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 1  25500         NaN      ford f-150       good        6.0  gas   88705.0
# 2   5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 3   1500      2003.0      ford f-150       fair        8.0  gas       NaN
# 4  14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
#
#   transmission    type paint_color  is_4wd date_posted  days_listed
# 0    automatic     SUV         NaN     1.0  2018-06-23           19
# 1    automatic  pickup       white     1.0  2018-10-19           50
# 2    automatic   sedan         red     NaN  2019-02-07           79
# 3    automatic  pickup         NaN     NaN  2019-03-22            9
# 4    automatic   sedan       black     NaN  2019-04-02           28

# %%
# obtaining general information about the data in df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    47906 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     46265 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB

# %%
#Calculating missing values
print(df.isna().sum())
# Out:
# price               0
# model_year       3619
# model               0
# condition           0
# cylinders        5260
# fuel                0
# odometer         7892
# transmission        0
# type                0
# paint_color      9267
# is_4wd          25953
# date_posted         0
# days_listed         0
# dtype: int64

# %% [markdown]
# We can see that there are many missing values. Some of the columns are less important than others. However, column 'model_year', in my opinion is important and we have to deal with missing values.

# %%
# In order to estimate missing values of 'model year' column, I used other related column, such as 'model' and took median value
df['model_year'] = df['model_year'].fillna(df.groupby(['model'])['model_year'].transform('median'))

# %%
#Identifying which columns has values that needs to be replaced
columns_to_replace = ['cylinders' , 'odometer', 'is_4wd']
columns_to_replace
# Out:
# ['cylinders', 'odometer', 'is_4wd']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    51525 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     46265 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB

# %%
#Looping over columns replacing missing values with 0
for column in columns_to_replace:
    print(column)
    df[column] = df[column].fillna(0)
    print('missing values in ', column, 'are replaced')
# Out:
# cylinders
# missing values in  cylinders are replaced
# odometer
# missing values in  odometer are replaced
# is_4wd
# missing values in  is_4wd are replaced

# %%
#Identifying one extra qualitative column to replace 
another_column_to_replace = ['paint_color']
another_column_to_replace
# Out:
# ['paint_color']

# %%
#Making another loop to replace that column 
for column in another_column_to_replace:
    print(column)
    df[column] = df[column].fillna('unknown')
    print('missing values in ', column, 'are replaced')
# Out:
# paint_color
# missing values in  paint_color are replaced

# %%
#Check to make sure that all NaNs are removed
print (df.isna().sum())
# Out:
# price           0
# model_year      0
# model           0
# condition       0
# cylinders       0
# fuel            0
# odometer        0
# transmission    0
# type            0
# paint_color     0
# is_4wd          0
# date_posted     0
# days_listed     0
# dtype: int64

# %%
df
# Out:
#        price  model_year           model  condition  cylinders fuel  odometer  \
# 0       9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 1      25500      2011.0      ford f-150       good        6.0  gas   88705.0
# 2       5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 3       1500      2003.0      ford f-150       fair        8.0  gas       0.0
# 4      14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
# ...      ...         ...             ...        ...        ...  ...       ...
# 51520   9249      2013.0   nissan maxima   like new        6.0  gas   88136.0
# 51521   2700      2002.0     honda civic    salvage        4.0  gas  181500.0
# 51522   3950      2009.0  hyundai sonata  excellent        4.0  gas  128000.0
# 51523   7455      2013.0  toyota corolla       good        4.0  gas  139573.0
# 51524   6300      2014.0   nissan altima       good        4.0  gas       0.0
#
#       transmission    type paint_color  is_4wd date_posted  days_listed
# 0        automatic     SUV     unknown     1.0  2018-06-23           19
# 1        automatic  pickup       white     1.0  2018-10-19           50
# 2        automatic   sedan         red     0.0  2019-02-07           79
# 3        automatic  pickup     unknown     0.0  2019-03-22            9
# 4        automatic   sedan       black     0.0  2019-04-02           28
# ...            ...     ...         ...     ...         ...          ...
# 51520    automatic   sedan       black     0.0  2018-10-03           37
# 51521    automatic   sedan       white     0.0  2018-11-14           22
# 51522    automatic   sedan        blue     0.0  2018-11-15           32
# 51523    automatic   sedan       black     0.0  2018-07-02           71
# 51524    automatic   sedan     unknown     0.0  2018-06-05           10
#
# [51525 rows x 13 columns]

# %%
# counting duplicates
df.duplicated().sum()
# Out:
# 0

# %%
#Inserting extra column in order to do filtering
df.insert(0, 'id', range(0, 0 + len(df)))
df
# Out:
#           id  price  model_year           model  condition  cylinders fuel  \
# 0          0   9400      2011.0          bmw x5       good        6.0  gas
# 1          1  25500      2011.0      ford f-150       good        6.0  gas
# 2          2   5500      2013.0  hyundai sonata   like new        4.0  gas
# 3          3   1500      2003.0      ford f-150       fair        8.0  gas
# 4          4  14900      2017.0    chrysler 200  excellent        4.0  gas
# ...      ...    ...         ...             ...        ...        ...  ...
# 51520  51520   9249      2013.0   nissan maxima   like new        6.0  gas
# 51521  51521   2700      2002.0     honda civic    salvage        4.0  gas
# 51522  51522   3950      2009.0  hyundai sonata  excellent        4.0  gas
# 51523  51523   7455      2013.0  toyota corolla       good        4.0  gas
# 51524  51524   6300      2014.0   nissan altima       good        4.0  gas
#
#        odometer transmission    type paint_color  is_4wd date_posted  \
# 0      145000.0    automatic     SUV     unknown     1.0  2018-06-23
# 1       88705.0    automatic  pickup       white     1.0  2018-10-19
# 2      110000.0    automatic   sedan         red     0.0  2019-02-07
# 3           0.0    automatic  pickup     unknown     0.0  2019-03-22
# 4       80903.0    automatic   sedan       black     0.0  2019-04-02
# ...         ...          ...     ...         ...     ...         ...
# 51520   88136.0    automatic   sedan       black     0.0  2018-10-03
# 51521  181500.0    automatic   sedan       white     0.0  2018-11-14
# 51522  128000.0    automatic   sedan        blue     0.0  2018-11-15
# 51523  139573.0    automatic   sedan       black     0.0  2018-07-02
# 51524       0.0    automatic   sedan     unknown     0.0  2018-06-05
#
#        days_listed
# 0               19
# 1               50
# 2               79
# 3                9
# 4               28
# ...            ...
# 51520           37
# 51521           22
# 51522           32
# 51523           71
# 51524           10
#
# [51525 rows x 14 columns]

# %%
# Table that shows how popular various types of vehicles 
st.write("""
### Proportion of different types of vehicles
""")
grouped_cars = df.groupby('type')['id'].nunique().reset_index()
st.table(grouped_cars)
grouped_cars
# Out:
#            type     id
# 0           SUV  12405
# 1           bus     24
# 2   convertible    446
# 3         coupe   2303
# 4     hatchback   1047
# 5      mini-van   1161
# 6       offroad    214
# 7         other    256
# 8        pickup   6988
# 9         sedan  12154
# 10        truck  12353
# 11          van    633
# 12        wagon   1541

# %%
#Bodystyle popularity sorted in descending order
grouped_bodystyle=df.groupby(['type'])['model'].nunique().reset_index()
grouped_bodystyle_sorted= grouped_bodystyle.sort_values(by = 'model',ascending=False)
grouped_bodystyle_sorted
# Out:
#            type  model
# 0           SUV     67
# 9         sedan     64
# 10        truck     59
# 7         other     57
# 12        wagon     54
# 8        pickup     41
# 4     hatchback     32
# 3         coupe     31
# 6       offroad     23
# 11          van     23
# 2   convertible     12
# 5      mini-van     10
# 1           bus      4

# %%
## pie plot Proportions of car bodystyles
pie = px.pie(grouped_cars, values=grouped_cars.id, names=grouped_cars.type)
pie.update_layout(title="<b> Proportions of car types")
st.plotly_chart(pie)
pie

# %% [markdown]
# As can be seen from the graph of the top 3 types of vehicles:
# - SUV (24.1%)
# - Truck (24%)
# - Sedan (23,6%)

# %%
#Average cost of a vehicle by different tyoe
average_cost_by_type=df.groupby(['type'])['price'].mean().sort_values(ascending=False)
average_cost_by_type
# Out:
# type
# bus            17135.666667
# truck          16734.894924
# pickup         16057.410418
# convertible    14575.881166
# coupe          14353.442901
# offroad        14292.294393
# SUV            11149.400000
# other          10989.714844
# van            10546.941548
# wagon           9088.134328
# mini-van        8193.177433
# sedan           6965.358647
# hatchback       6868.513849
# Name: price, dtype: float64

# %%
histogram = px.bar(grouped_bodystyle_sorted, x=grouped_bodystyle_sorted.type, y=grouped_bodystyle_sorted.model)
histogram.update_layout(title="<b> Popularity of the bodystyle")
st.plotly_chart(histogram)
histogram

# %% [markdown]
# As can be seen from the graph of the top 3 types of vehicles by the number in the data:
# - SUV with 12405 vehicles
# - Truck with 12353 vehicles
# - Sedan 12154 vehicles

# %%
# Scatter plot
fig = px.scatter(df, x='model', y='price', color='type',
                  labels={
                     'model' : 'Model',
                     'price' : 'Price',
                     'type' : 'Type'
                 },
                 title ='Prices of vehicles based on model')
fig.show()

# %% [markdown]
# Graph shows that one model of vehicle has a wae range of prices. There are also clear outliers in terms of price, like 375k for Nissan Frontier, given that its range of prices is within 0-17k.

# %%
# Scatter plot 2
fig = px.scatter(df, x='model_year', y='price', color='condition',
                 labels={
                     'model_year' : 'Year',
                     'price' : 'Price',
                     'condition' : 'Condition'
                 },
                 title ='Prices of vehicles based on their year')
fig

# %% [markdown]
# This scatterplot shows that vehicles that were made from 1975 to around 2000 has little price changes with regards to its sale price. However, for those vehicles that were produced after 2000, especially after 2005, the range of sale prices for those vehicles increase dramatically. From 0 to around 20k for a car made in 1986 to price range from 1 to 85k for a car made in 2019. More recently made vehicles are sold at much wider price range than older cars.
